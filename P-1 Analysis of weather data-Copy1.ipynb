# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data =pd.read_csv(r'C:\Users\satis\Real Project using python\weather.csv')

# %%
data
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
#1  .head()
data.head()
# Out:
#    Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                0.00  2016-01-03           1             3       2016
# 1                0.00  2016-01-03           1             3       2016
# 2                0.16  2016-01-03           1             3       2016
# 3                0.00  2016-01-03           1             3       2016
# 4                0.01  2016-01-03           1             3       2016
#
#   Station.City Station.Code Station.Location Station.State  \
# 0   Birmingham          BHM   Birmingham, AL       Alabama
# 1   Huntsville          HSV   Huntsville, AL       Alabama
# 2       Mobile          MOB       Mobile, AL       Alabama
# 3   Montgomery          MGM   Montgomery, AL       Alabama
# 4    Anchorage          ANC    Anchorage, AK        Alaska
#
#    Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 0                         39                         46
# 1                         39                         47
# ...

# %%
data.shape  #showing shape of the columns
# Out:
# (16743, 14)

# %%
data.index     #showing index of the columns
# Out:
# RangeIndex(start=0, stop=16743, step=1)

# %%
data.columns     #showing name of the columns
# Out:
# Index(['Data.Precipitation', 'Date.Full', 'Date.Month', 'Date.Week of',
#        'Date.Year', 'Station.City', 'Station.Code', 'Station.Location',
#        'Station.State', 'Data.Temperature.Avg Temp',
#        'Data.Temperature.Max Temp', 'Data.Temperature.Min Temp',
#        'Data.Wind.Direction', 'Data.Wind.Speed'],
#       dtype='object')

# %%
data.dtypes     #showing type of data
# Out:
# Data.Precipitation           float64
# Date.Full                     object
# Date.Month                     int64
# Date.Week of                   int64
# Date.Year                      int64
# Station.City                  object
# Station.Code                  object
# Station.Location              object
# Station.State                 object
# Data.Temperature.Avg Temp      int64
# Data.Temperature.Max Temp      int64
# Data.Temperature.Min Temp      int64
# Data.Wind.Direction            int64
# Data.Wind.Speed              float64
# dtype: object

# %%
data['Station.State'].unique()    #showing all name or number inside the perticular columns
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'DE', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Puerto Rico', 'Rhode Island',
#        'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah',
#        'VA', 'Vermont', 'Virginia', 'Washington', 'West Virginia',
#        'Wisconsin', 'Wyoming'], dtype=object)

# %%
data.nunique()      #showing total no of unique values in single columns as well as whole dataframe
# Out:
# Data.Precipitation            565
# Date.Full                      53
# Date.Month                     12
# Date.Week of                   31
# Date.Year                       2
# Station.City                  307
# Station.Code                  318
# Station.Location              318
# Station.State                  53
# Data.Temperature.Avg Temp     119
# Data.Temperature.Max Temp     125
# Data.Temperature.Min Temp     114
# Data.Wind.Direction            37
# Data.Wind.Speed              1461
# dtype: int64

# %%
data.count()
# Out:
# Data.Precipitation           16743
# Date.Full                    16743
# Date.Month                   16743
# Date.Week of                 16743
# Date.Year                    16743
# Station.City                 16743
# Station.Code                 16743
# Station.Location             16743
# Station.State                16743
# Data.Temperature.Avg Temp    16743
# Data.Temperature.Max Temp    16743
# Data.Temperature.Min Temp    16743
# Data.Wind.Direction          16743
# Data.Wind.Speed              16743
# dtype: int64

# %%
data['Station.State'].value_counts()
# Out:
# Alaska            1719
# Texas             1272
# California         999
# Florida            636
# Montana            583
# Michigan           477
# Nebraska           424
# New York           424
# Oregon             424
# Tennessee          420
# Pennsylvania       371
# Mississippi        371
# Ohio               371
# North Carolina     371
# Washington         371
# Missouri           371
# Georgia            318
# Illinois           318
# Kansas             318
# Nevada             318
# Colorado           318
# Virginia           318
# South Dakota       265
# North Dakota       265
# Wyoming            265
# Minnesota          265
# Arizona            265
# Hawaii             265
# Kentucky           265
# Iowa               265
# Louisiana          261
# Oklahoma           212
# Wisconsin          212
# West Virginia      212
# South Carolina     212
# Alabama            212
# Indiana            212
# Idaho              159
# New Mexico         159
# Maine              159
# ...

# %%
data.info() #all infomations about the data with memory uses
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16743 entries, 0 to 16742
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Data.Precipitation         16743 non-null  float64
#  1   Date.Full                  16743 non-null  object
#  2   Date.Month                 16743 non-null  int64
#  3   Date.Week of               16743 non-null  int64
#  4   Date.Year                  16743 non-null  int64
#  5   Station.City               16743 non-null  object
#  6   Station.Code               16743 non-null  object
#  7   Station.Location           16743 non-null  object
#  8   Station.State              16743 non-null  object
#  9   Data.Temperature.Avg Temp  16743 non-null  int64
#  10  Data.Temperature.Max Temp  16743 non-null  int64
#  11  Data.Temperature.Min Temp  16743 non-null  int64
#  12  Data.Wind.Direction        16743 non-null  int64
# ...

# %%
#Unique wind Speed
data['Data.Wind.Speed'].nunique()
# Out:
# 1461

# %%
data['Data.Wind.Speed'].unique()    #Answer
# Out:
# array([ 4.33,  3.86,  9.73, ..., 12.53, 19.98, 18.16])

# %% [markdown]
# #Find the no of place ?

# %%
data.head(2)
# Out:
#    Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                 0.0  2016-01-03           1             3       2016
# 1                 0.0  2016-01-03           1             3       2016
#
#   Station.City Station.Code Station.Location Station.State  \
# 0   Birmingham          BHM   Birmingham, AL       Alabama
# 1   Huntsville          HSV   Huntsville, AL       Alabama
#
#    Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 0                         39                         46
# 1                         39                         47
#
#    Data.Temperature.Min Temp  Data.Wind.Direction  Data.Wind.Speed
# 0                         32                   33             4.33
# 1                         31                   32             3.86

# %%
#using value count
data['Station.State'].value_counts()
# Out:
# Alaska            1719
# Texas             1272
# California         999
# Florida            636
# Montana            583
# Michigan           477
# Nebraska           424
# New York           424
# Oregon             424
# Tennessee          420
# Pennsylvania       371
# Mississippi        371
# Ohio               371
# North Carolina     371
# Washington         371
# Missouri           371
# Georgia            318
# Illinois           318
# Kansas             318
# Nevada             318
# Colorado           318
# Virginia           318
# South Dakota       265
# North Dakota       265
# Wyoming            265
# Minnesota          265
# Arizona            265
# Hawaii             265
# Kentucky           265
# Iowa               265
# Louisiana          261
# Oklahoma           212
# Wisconsin          212
# West Virginia      212
# South Carolina     212
# Alabama            212
# Indiana            212
# Idaho              159
# New Mexico         159
# Maine              159
# ...

# %%
#by Filtering
data[data['Station.State']=='Alaska']
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 4                    0.01  2016-01-03           1             3       2016
# 5                    0.09  2016-01-03           1             3       2016
# 6                    0.05  2016-01-03           1             3       2016
# 7                    0.15  2016-01-03           1             3       2016
# 8                    0.60  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16459                0.00  2017-01-01           1             1       2017
# 16460                0.00  2017-01-01           1             1       2017
# 16461                0.17  2017-01-01           1             1       2017
# 16462                0.00  2017-01-01           1             1       2017
# 16463                1.40  2017-01-01           1             1       2017
#
# ...

# %%
#by Groupby 
data.groupby('Station.State').get_group('Alaska')
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 4                    0.01  2016-01-03           1             3       2016
# 5                    0.09  2016-01-03           1             3       2016
# 6                    0.05  2016-01-03           1             3       2016
# 7                    0.15  2016-01-03           1             3       2016
# 8                    0.60  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16459                0.00  2017-01-01           1             1       2017
# 16460                0.00  2017-01-01           1             1       2017
# 16461                0.17  2017-01-01           1             1       2017
# 16462                0.00  2017-01-01           1             1       2017
# 16463                1.40  2017-01-01           1             1       2017
#
# ...

# %% [markdown]
# # Find the number of time where the wind direction was 10 ?

# %%
data['Data.Wind.Direction']==10    #Boolian format
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16738    False
# 16739    False
# 16740    False
# 16741    False
# 16742    False
# Name: Data.Wind.Direction, Length: 16743, dtype: bool

# %%
data[data['Data.Wind.Direction']==10]  #value format
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 15                   0.70  2016-01-03           1             3       2016
# 18                   0.05  2016-01-03           1             3       2016
# 57                   0.04  2016-01-03           1             3       2016
# 243                  0.05  2016-01-03           1             3       2016
# 335                  0.03  2016-01-10           1            10       2016
# ...                   ...         ...         ...           ...        ...
# 16442                0.86  2017-01-01           1             1       2017
# 16458                0.37  2017-01-01           1             1       2017
# 16467                0.35  2017-01-01           1             1       2017
# 16477                0.00  2017-01-01           1             1       2017
# 16479                0.27  2017-01-01           1             1       2017
#
# ...

# %% [markdown]
# #Find out all the value of data?

# %%
data.isnull()   #boolian form
# Out:
#        Data.Precipitation  Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                   False      False       False         False      False
# 1                   False      False       False         False      False
# 2                   False      False       False         False      False
# 3                   False      False       False         False      False
# 4                   False      False       False         False      False
# ...                   ...        ...         ...           ...        ...
# 16738               False      False       False         False      False
# 16739               False      False       False         False      False
# 16740               False      False       False         False      False
# 16741               False      False       False         False      False
# 16742               False      False       False         False      False
#
#        Station.City  Station.Code  Station.Location  Station.State  \
# ...

# %%
data.isnull().sum()    #sum form
# Out:
# Data.Precipitation           0
# Date.Full                    0
# Date.Month                   0
# Date.Week of                 0
# Date.Year                    0
# Station.City                 0
# Station.Code                 0
# Station.Location             0
# Station.State                0
# Data.Temperature.Avg Temp    0
# Data.Temperature.Max Temp    0
# Data.Temperature.Min Temp    0
# Data.Wind.Direction          0
# Data.Wind.Speed              0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Data.Precipitation           16743
# Date.Full                    16743
# Date.Month                   16743
# Date.Week of                 16743
# Date.Year                    16743
# Station.City                 16743
# Station.Code                 16743
# Station.Location             16743
# Station.State                16743
# Data.Temperature.Avg Temp    16743
# Data.Temperature.Max Temp    16743
# Data.Temperature.Min Temp    16743
# Data.Wind.Direction          16743
# Data.Wind.Speed              16743
# dtype: int64

# %% [markdown]
# # Rename the columns name'Station.State' to 'USAStation.State'.

# %%
data.rename(columns={'Station.State':'USAStation.State'})  #rename the columns temporarily
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location USAStation.State  \
# ...

# %%
data.rename(columns={'Station.State':'USAStation.State'}, inplace=True)  #rename the columns permanently

# %% [markdown]
# # Mean wind speed

# %%
data.head(2)
# Out:
#    Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                 0.0  2016-01-03           1             3       2016
# 1                 0.0  2016-01-03           1             3       2016
#
#   Station.City Station.Code Station.Location USAStation.State  \
# 0   Birmingham          BHM   Birmingham, AL          Alabama
# 1   Huntsville          HSV   Huntsville, AL          Alabama
#
#    Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 0                         39                         46
# 1                         39                         47
#
#    Data.Temperature.Min Temp  Data.Wind.Direction  Data.Wind.Speed
# 0                         32                   33             4.33
# 1                         31                   32             3.86

# %%
data['Data.Wind.Speed'].mean()
# Out:
# 6.3298202233769345

# %%
#Standard deviations of max temp
data['Data.Temperature.Max Temp'].std()
# Out:
# 19.78795411795669

# %% [markdown]
# # variance of the Data.Temperature.Avg Temp

# %%
data['Data.Temperature.Avg Temp'].var()
# Out:
# 353.37588371123354

# %%
data.head(2)
# Out:
#    Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                 0.0  2016-01-03           1             3       2016
# 1                 0.0  2016-01-03           1             3       2016
#
#   Station.City Station.Code Station.Location USAStation.State  \
# 0   Birmingham          BHM   Birmingham, AL          Alabama
# 1   Huntsville          HSV   Huntsville, AL          Alabama
#
#    Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 0                         39                         46
# 1                         39                         47
#
#    Data.Temperature.Min Temp  Data.Wind.Direction  Data.Wind.Speed
# 0                         32                   33             4.33
# 1                         31                   32             3.86

# %% [markdown]
# # find all the USAStation.State where wind direction is more than 30

# %%
data[data['Data.Wind.Direction']>30]
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 43                   0.00  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16164                0.94  2016-12-25          12            25       2016
# 16451                0.22  2017-01-01           1             1       2017
# 16473                0.00  2017-01-01           1             1       2017
# 16480                0.00  2017-01-01           1             1       2017
# 16481                0.00  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location USAStation.State  \
# ...

# %% [markdown]
# # Find all the Data.Temperature.Avg Temp greater than 25 where wind direction is more than 30

# %%
data[(data['Data.Wind.Direction']>30) &  (data['Data.Temperature.Avg Temp']>=25)]
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 43                   0.00  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16163                0.55  2016-12-25          12            25       2016
# 16164                0.94  2016-12-25          12            25       2016
# 16473                0.00  2017-01-01           1             1       2017
# 16480                0.00  2017-01-01           1             1       2017
# 16481                0.00  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location USAStation.State  \
# ...

# %% [markdown]
# # mean value of Data.Wind.Speed

# %%
data['Data.Wind.Speed'].mean()
# Out:
# 6.3298202233769345

# %% [markdown]
# # mean value of each column againsed each station

# %%
data.groupby('USAStation.State').mean()
# Out:
#                   Data.Precipitation  Date.Month  Date.Week of    Date.Year  \
# USAStation.State
# Alabama                     0.776179    6.339623     15.660377  2016.018868
# Alaska                      0.566126    6.392670     15.603839  2016.019779
# Arizona                     0.162566    6.339623     15.660377  2016.018868
# Arkansas                    0.603711    6.339623     15.660377  2016.018868
# California                  0.323774    6.308308     15.666667  2016.018018
# Colorado                    0.182987    6.339623     15.660377  2016.018868
# Connecticut                 0.587830    6.339623     15.660377  2016.018868
# DE                          0.632453    6.339623     15.660377  2016.018868
# Delaware                    0.632453    6.339623     15.660377  2016.018868
# Florida                     0.891006    6.339623     15.660377  2016.018868
# Georgia                     0.712799    6.339623     15.660377  2016.018868
# ...

# %% [markdown]
# # min and Max value of each columns

# %%
data.groupby('Data.Wind.Speed').min()
# Out:
#                  Data.Precipitation   Date.Full  Date.Month  Date.Week of  \
# Data.Wind.Speed
# 0.00                           0.00  2016-01-03           1             1
# 0.15                           0.00  2016-03-06           3             6
# 0.18                           0.00  2016-02-14           2            14
# 0.20                           0.00  2016-05-01           5             1
# 0.25                           0.00  2016-08-28           8             4
# ...                             ...         ...         ...           ...
# 47.56                          2.71  2017-01-01           1             1
# 49.60                          2.42  2016-12-18          12            18
# 50.06                          0.00  2016-04-03           4             3
# 52.60                          0.00  2016-01-03           1             3
# 61.10                          0.00  2016-03-06           3             6
#
# ...

# %%
data.groupby('Data.Wind.Speed').max()
# Out:
#                  Data.Precipitation   Date.Full  Date.Month  Date.Week of  \
# Data.Wind.Speed
# 0.00                           6.08  2017-01-01          12            31
# 0.15                           0.00  2016-03-06           3             6
# 0.18                           2.04  2016-07-31           7            31
# 0.20                           2.08  2016-12-18          12            18
# 0.25                           0.00  2016-09-04           9            28
# ...                             ...         ...         ...           ...
# 47.56                          2.71  2017-01-01           1             1
# 49.60                          2.42  2016-12-18          12            18
# 50.06                          0.00  2016-04-03           4             3
# 52.60                          0.00  2016-01-03           1             3
# 61.10                          0.00  2016-03-06           3             6
#
# ...

# %%
df= pd.DataFrame(data)
newdf= df.drop('Data.Precipitation',
               axis='columns')

# %%
newdf
# Out:
#         Date.Full  Date.Month  Date.Week of  Date.Year Station.City  \
# 0      2016-01-03           1             3       2016   Birmingham
# 1      2016-01-03           1             3       2016   Huntsville
# 2      2016-01-03           1             3       2016       Mobile
# 3      2016-01-03           1             3       2016   Montgomery
# 4      2016-01-03           1             3       2016    Anchorage
# ...           ...         ...           ...        ...          ...
# 16738  2017-01-01           1             1       2017       Casper
# 16739  2017-01-01           1             1       2017     Cheyenne
# 16740  2017-01-01           1             1       2017       Lander
# 16741  2017-01-01           1             1       2017      Rawlins
# 16742  2017-01-01           1             1       2017     Sheridan
#
#       Station.Code Station.Location USAStation.State  \
# 0              BHM   Birmingham, AL          Alabama
# ...

# %%
df= pd.DataFrame(data)
newdf1= df.drop(['Data.Precipitation','Date.Full','Date.Month','Date.Week of','Date.Year'],
               axis='columns')

# %%
newdf1
# Out:
#       Station.City Station.Code Station.Location USAStation.State  \
# 0       Birmingham          BHM   Birmingham, AL          Alabama
# 1       Huntsville          HSV   Huntsville, AL          Alabama
# 2           Mobile          MOB       Mobile, AL          Alabama
# 3       Montgomery          MGM   Montgomery, AL          Alabama
# 4        Anchorage          ANC    Anchorage, AK           Alaska
# ...            ...          ...              ...              ...
# 16738       Casper          CPR       Casper, WY          Wyoming
# 16739     Cheyenne          CYS     Cheyenne, WY          Wyoming
# 16740       Lander          LND       Lander, WY          Wyoming
# 16741      Rawlins          RWL      Rawlins, WY          Wyoming
# 16742     Sheridan          SHR     Sheridan, WY          Wyoming
#
#        Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 0                             39                         46
# ...

# %%
newdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16743 entries, 0 to 16742
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Station.City               16743 non-null  object
#  1   Station.Code               16743 non-null  object
#  2   Station.Location           16743 non-null  object
#  3   USAStation.State           16743 non-null  object
#  4   Data.Temperature.Avg Temp  16743 non-null  int64
#  5   Data.Temperature.Max Temp  16743 non-null  int64
#  6   Data.Temperature.Min Temp  16743 non-null  int64
#  7   Data.Wind.Direction        16743 non-null  int64
#  8   Data.Wind.Speed            16743 non-null  float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 1.1+ MB

# %%
st_temp=sns.boxplot(x='USAStation.State',y='Data.Temperature.Avg Temp',data=newdf1)
st_temp.set_xticklabels(st_temp.get_xticklabels(),rotation=90
                       ,horizontalalignment='right');
plt.title('City wise Avg Temp')
# Out:
# Text(0.5, 1.0, 'City wise Avg Temp')

# %%
newdf1.describe()
# Out:
#        Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# count               16743.000000               16743.000000
# mean                   56.089112                  66.042406
# std                    18.798295                  19.787954
# min                   -27.000000                 -19.000000
# 25%                    44.000000                  53.000000
# 50%                    58.000000                  68.000000
# 75%                    71.000000                  82.000000
# max                   100.000000                 111.000000
#
#        Data.Temperature.Min Temp  Data.Wind.Direction  Data.Wind.Speed
# count               16743.000000         16743.000000     16743.000000
# mean                   45.642716            18.791316         6.329820
# std                    18.559263             6.461527         3.494785
# min                   -35.000000             0.000000         0.000000
# ...

# %%
newdf1.hist();
